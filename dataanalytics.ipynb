# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20.0 ,10.0)

data = pd.read_csv(r"C:\Users\Keshav Pathak\Desktop\headbrain.csv")
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = data['Head Size(cm^3)'].values
Y = data['Brain Weight(grams)'].values

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(X)

numer = 0
denom = 0
for i in range(m):
    numer += (x[i]-mean_x)*(Y[i]-mean_y)
    denom += (x[i]-mean_x)**2
b1 = numer/denom
b0 = mean_y - (b1 * mean_x)


print(b1,b0)
# Out:
# -0.0159070069444023 1340.6793467211314

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

x = np.linspace(min_x,max_x,1000)
y = b1*x + b0


plt.plot(x,y,label = 'regression line')
plt.scatter(X,Y,label = 'scatter plot')


plt.xlabel('head size in cm')
plt.ylabel('brain weight in gm')
plt.legend()
plt.show()
